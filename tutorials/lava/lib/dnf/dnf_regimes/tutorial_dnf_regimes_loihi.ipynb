# %% [markdown]
# *Copyright (C) 2021 Intel Corporation*<br>
# *SPDX-License-Identifier: BSD-3-Clause*<br>
# *See: https://spdx.org/licenses/*
#
# ---
#
# # DNF regimes
#
# The following examples demonstrate the fundamental regimes of
# DNFs and their associated instabilities that are the basis for all
# macroscopic behavior of architectures.

# %% [markdown]
# ### Check Whether Loihi 2 is Available

# %%
from lava.utils.system import Loihi2
Loihi2.preferred_partition = 'kp_stack'
loihi2_is_available = Loihi2.is_loihi2_available

if loihi2_is_available:
    print(f'Running on {Loihi2.partition}')
    
else:
    print("Loihi2 compiler is not available in this system. "
          "This tutorial will execute on CPU backend.")
# Out:
# Running on kp_stack

# %%
import numpy as np
from lava.proc.lif.process import LIF
from lava.proc.monitor.process import Monitor
from lava.proc.monitor.models import PyMonitorModel
from lava.proc.embedded_io.spike import PyToNxAdapter, NxToPyAdapter
from lava.proc.dense.process import Dense
from lava.proc.io.sink import RingBuffer
from lava.magma.core.run_configs import Loihi1SimCfg, Loihi2HwCfg
from lava.magma.core.run_conditions import RunSteps
from lava.lib.dnf.connect.connect import connect
from lava.lib.dnf.operations.operations import Weights, Convolution
from lava.lib.dnf.inputs.gauss_pattern.process import GaussPattern
from lava.lib.dnf.inputs.rate_code_spike_gen.process import RateCodeSpikeGen
from lava.lib.dnf.kernels.kernels import Kernel
from utils import plot_1d, animated_1d_plot

class Architecture:
    """This class structure is not required and is only used here to reduce
    code duplication for different examples.
    The Architecture is as follows
    
    GaussPattern1 (PyProc)-> SpikeGenerator1 (PyProc)-> Injector1(CProc)-> DNF (NcProc)-> Spikereader (CProc)-> PyReceiver (PyProc)
                                                                             ^
                                                                             |
    GaussPattern2 (PyProc)-> SpikeGenerator2 (PyProc)-> Injector2(CProc)-----
    
    """

    def __init__(self,
                 kernel: Kernel) -> None:
        shape = (15,)
        time_steps = 700
        
        # Instantiate Processes
        self.gauss_pattern_1 = GaussPattern(shape=shape,
                                            amplitude=0,
                                            mean=11.25,
                                            stddev=2.25)
        self.gauss_pattern_2 = GaussPattern(shape=shape,
                                            amplitude=0,
                                            mean=3.75,
                                            stddev=2.25)

        self.spike_generator_1 = RateCodeSpikeGen(shape=shape)
        self.spike_generator_2 = RateCodeSpikeGen(shape=shape)
        self.input_dense1 = Dense(weights=np.eye(shape[0]) * 25)
        self.input_dense2 = Dense(weights=np.eye(shape[0]) * 25)
        self.dnf = LIF(shape=shape, du=409, dv=2047, vth=200)
        self.py_receiver = RingBuffer(shape=shape, buffer=time_steps)
        
        # When running on Loihi 2 we additionally have spike injector and reader CProcesses. 
        # They bridge Python and NC-Processes
        if loihi2_is_available:
            self.injector1 = PyToNxAdapter(shape=shape)
            self.injector2 = PyToNxAdapter(shape=shape)
            self.spike_reader = NxToPyAdapter(shape=shape)
        
        
        # Make Connections of the Network
        self.gauss_pattern_1.a_out.connect(self.spike_generator_1.a_in)
        self.gauss_pattern_2.a_out.connect(self.spike_generator_2.a_in)

        if loihi2_is_available:
            self.spike_generator_1.s_out.connect(self.injector1.inp)
            self.spike_generator_2.s_out.connect(self.injector2.inp)
            self.injector1.out.connect(self.input_dense1.s_in)
            self.injector2.out.connect(self.input_dense2.s_in)
        else:
            self.spike_generator_1.s_out.connect(self.input_dense1.s_in)
            self.spike_generator_2.s_out.connect(self.input_dense2.s_in)

        self.input_dense1.a_out.connect(self.dnf.a_in)
        self.input_dense2.a_out.connect(self.dnf.a_in)
        connect(self.dnf.s_out, self.dnf.a_in, [Convolution(kernel)])
            
        if loihi2_is_available:
            self.dnf.s_out.connect(self.spike_reader.inp)
            self.spike_reader.out.connect(self.py_receiver.a_in)
        else:
            self.dnf.s_out.connect(self.py_receiver.a_in)
        
        # Set up mointors
        self.monitor_input_1 = Monitor()
        self.monitor_input_1.probe(self.spike_generator_1.s_out, time_steps)
        self.monitor_input_2 = Monitor()
        self.monitor_input_2.probe(self.spike_generator_2.s_out, time_steps)

        # Set up a run configuration
        if loihi2_is_available:
            self.run_cfg = Loihi2HwCfg()
        else:
            self.run_cfg = Loihi1SimCfg(select_tag="fixed_pt")

    def run(self):
        condition = RunSteps(num_steps=100)
        self.gauss_pattern_1.run(condition=condition, run_cfg=self.run_cfg)
        self.gauss_pattern_1.amplitude = 2300
        self.gauss_pattern_2.amplitude = 2300
        self.gauss_pattern_1.run(condition=condition, run_cfg=self.run_cfg)
        self.gauss_pattern_1.amplitude = 11200
        self.gauss_pattern_2.amplitude = 11200
        self.gauss_pattern_1.run(condition=condition, run_cfg=self.run_cfg)
        self.gauss_pattern_1.amplitude = 2300
        self.gauss_pattern_2.amplitude = 2300
        self.gauss_pattern_1.run(condition=RunSteps(num_steps=200),
                                 run_cfg=self.run_cfg)
        self.gauss_pattern_1.amplitude = 0
        self.gauss_pattern_2.amplitude = 0
        self.gauss_pattern_1.run(condition=RunSteps(num_steps=200),
                                 run_cfg=self.run_cfg)


    def plot(self):
        # Get probed data from monitors
        data_dnf = self.py_receiver.data.get().transpose()
        data_input1 = self.monitor_input_1.get_data() \
            [self.spike_generator_1.name][self.spike_generator_1.s_out.name]
        data_input2 = self.monitor_input_2.get_data() \
            [self.spike_generator_2.name][self.spike_generator_2.s_out.name]

        # Stop the execution of the network
        self.dnf.stop()

        # Generate a raster plot from the probed data
        plot_1d(data_dnf,
                data_input1,
                data_input2)

        # Generate an animated plot from the probed data
        animated_1d_plot(data_dnf,
                         data_input1,
                         data_input2)

# %% [markdown]
# ## Detection
#
# This example demonstrates the _detection instability_ of DNFs. The DNF receives spike input at two locations, whose spike rate changes over time. Between time step 100 and 200, the spike rate is not high enough for the DNF to form a peak and it does not spike. When the input spike rate is increased after time step 200, the DNF goes through the _detection instability_, forming a peak and producing spike output. When the input spike rate is lowered back to its previous value, the DNF keeps spiking and its peak remains stable. This demonstrates hysteresis of detection - the DNF stabilizes its decision about detecting an input. Only when the input is completely removed at time step 500 does the peak disappear in the _reverse detection instability_.

# %%
from lava.lib.dnf.kernels.kernels import MultiPeakKernel

detection_kernel = MultiPeakKernel(amp_exc=83, 
                                   width_exc=3.75, 
                                   amp_inh=-70,
                                   width_inh=7.5)

architecture = Architecture(detection_kernel)
architecture.run()
architecture.plot()
# Out:
# Per core distribution:
# ----------------------------------------------------------------
# | AxonIn |NeuronGr| Neurons|Synapses| AxonMap| AxonMem|  Cores |
# |--------------------------------------------------------------|
# |      45|       1|      15|     210|      15|       0|       1|
# |--------------------------------------------------------------|
# | Total                                               |       1|
# ----------------------------------------------------------------
# WARNING:DRV:  ~/lava/frameworks.ai.nx.nxsdk ~/lava/lava-dnf/tutorials/lava/lib/dnf/dnf_regimes
# Compiling in directory : /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015
# Include dir is : /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports -I/home/sveamari/lava/frameworks.ai.lava.lava/src/lava/proc/embedded_io -I/home/sveamari/lava/frameworks.ai.lava.lava/src/lava/proc/embedded_io/tmpk45tiaoc
# Compiling -c /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/initnetwork_0_0.c
# gcc -Wall -I/home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports -I/home/sveamari/lava/frameworks.ai.lava.lava/src/lava/proc/embedded_io -I/home/sveamari/lava/frameworks.ai.lava.lava/src/lava/proc/embedded_io/tmpk45tiaoc -Inxcore/include -D N3 -D N3B -D N3B3 -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -fcf-protection=none -fno-pie -no-pie -Os -DNDEBUG -std=c99 -o /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/initnetwork_0_0.c.o -c /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/initnetwork_0_0.c
# Compiling without -c /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/0_nx_to_py_adapter.c
# gcc -Wall -I/home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports -I/home/sveamari/lava/frameworks.ai.lava.lava/src/lava/proc/embedded_io -I/home/sveamari/lava/frameworks.ai.lava.lava/src/lava/proc/embedded_io/tmpk45tiaoc -Inxcore/include -D N3 -D N3B -D N3B3 -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -fcf-protection=none -fno-pie -no-pie -Os -DNDEBUG -std=c99 -o /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/0_nx_to_py_adapter.c.o -c /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/0_nx_to_py_adapter.c
# In file included from /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/proc/embedded_io/tmpk45tiaoc/predefs_NxToPyAdapterModel.h:1,
#                  from /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/proc/embedded_io/spike_snips/nx_to_py_adapter.c:18:
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h: In function ‘read_graded_spike_counter’:
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:306:3: warning: implicit declaration of function ‘nx_read’ [-Wimplicit-function-declaration]
#   306 |   nx_read(&value, dst, sizeof(value));
#       |   ^~~~~~~
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:309:3: warning: implicit declaration of function ‘nx_write’ [-Wimplicit-function-declaration]
#   309 |   nx_write(dst, &value, sizeof(value));
#       |   ^~~~~~~~
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h: In function ‘send_seq_dense’:
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:543:35: warning: passing argument 6 of ‘inject_spike_for_axon’ makes integer from pointer without a cast [-Wint-conversion]
#   543 |                 port->spike_type, &data);
#       |                                   ^~~~~
#       |                                   |
#       |                                   uint32_t ** {aka unsigned int **}
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:366:36: note: expected ‘uint32_t’ {aka ‘unsigned int’} but argument is of type ‘uint32_t **’ {aka ‘unsigned int **’}
#   366 |                           uint32_t data) {
#       |                           ~~~~~~~~~^~~~
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h: In function ‘done_send_seq_dense’:
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:599:12: warning: passing argument 1 of ‘memset’ makes pointer from integer without a cast [-Wint-conversion]
#   599 |     memset(out_buffer_idx, 0, MESSAGE_SIZE * sizeof(uint32_t));
#       |            ^~~~~~~~~~~~~~
#       |            |
#       |            uint8_t {aka unsigned char}
# In file included from /usr/include/features.h:461,
#                  from /usr/include/bits/libc-header-start.h:33,
#                  from /usr/include/stdint.h:26,
#                  from /usr/lib/gcc/x86_64-linux-gnu/9/include/stdint.h:9,
#                  from nxcore/include/n3sdk.h:31,
#                  from nxcore/include/nxsdk.h:30,
#                  from /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/0_nx_to_py_adapter.c:1:
# /usr/include/bits/string_fortified.h:59:1: note: expected ‘void *’ but argument is of type ‘uint8_t’ {aka ‘unsigned char’}
#    59 | __NTH (memset (void *__dest, int __ch, size_t __len))
#       | ^~~~~
# In file included from /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/proc/embedded_io/tmpk45tiaoc/predefs_NxToPyAdapterModel.h:1,
#                  from /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/proc/embedded_io/spike_snips/nx_to_py_adapter.c:18:
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h: In function ‘send_seq_sparse’:
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:667:20: warning: comparison between pointer and integer
#   667 |           if (cntr == idx) {
#       |                    ^~
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:672:35: warning: passing argument 6 of ‘inject_spike_for_axon’ makes integer from pointer without a cast [-Wint-conversion]
#   672 |                 port->spike_type, &data);
#       |                                   ^~~~~
#       |                                   |
#       |                                   uint32_t ** {aka unsigned int **}
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:366:36: note: expected ‘uint32_t’ {aka ‘unsigned int’} but argument is of type ‘uint32_t **’ {aka ‘unsigned int **’}
#   366 |                           uint32_t data) {
#       |                           ~~~~~~~~~^~~~
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h: In function ‘send_seq_conv’:
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:735:24: warning: suggest parentheses around arithmetic in operand of ‘|’ [-Wparentheses]
#   735 |   axon = 0x4000 | axon & 0xFF;
#       |                   ~~~~~^~~~~~
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:736:60: warning: suggest parentheses around arithmetic in operand of ‘|’ [-Wparentheses]
#   736 |   uint64_t encoded_data = (payload & 0xFFFF) << 16 | *data & 0xFFFF;
#       |                                                      ~~~~~~^~~~~~~~
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h: In function ‘recv_vec_dense’:
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:826:20: warning: comparison between pointer and integer
#   826 |         if (header != SEQ_DENSE) {
#       |                    ^~
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h: In function ‘recv_seq_sparse’:
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:1127:20: warning: comparison between pointer and integer
#  1127 |           if (cntr == idx) {
#       |                    ^~
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/proc/embedded_io/spike_snips/nx_to_py_adapter.c: In function ‘run_post_mgmt’:
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/proc/embedded_io/spike_snips/nx_to_py_adapter.c:35:30: warning: pointer targets in passing argument 3 of ‘recv_vec_dense’ differ in signedness [-Wpointer-sign]
#    35 |     recv_vec_dense(rs, &inp, data);
#       |                              ^~~~
#       |                              |
#       |                              int32_t * {aka int *}
# In file included from /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/proc/embedded_io/tmpk45tiaoc/predefs_NxToPyAdapterModel.h:1,
#                  from /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/proc/embedded_io/spike_snips/nx_to_py_adapter.c:18:
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:769:64: note: expected ‘uint32_t *’ {aka ‘unsigned int *’} but argument is of type ‘int32_t *’ {aka ‘int *’}
#   769 | int recv_vec_dense(runState *s, struct InPort *port, uint32_t *data) {
#       |                                                      ~~~~~~~~~~^~~~
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/proc/embedded_io/spike_snips/nx_to_py_adapter.c:36:30: warning: pointer targets in passing argument 3 of ‘send_vec_dense’ differ in signedness [-Wpointer-sign]
#    36 |     send_vec_dense(rs, &out, data);
#       |                              ^~~~
#       |                              |
#       |                              int32_t * {aka int *}
# In file included from /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/proc/embedded_io/tmpk45tiaoc/predefs_NxToPyAdapterModel.h:1,
#                  from /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/proc/embedded_io/spike_snips/nx_to_py_adapter.c:18:
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:402:65: note: expected ‘uint32_t *’ {aka ‘unsigned int *’} but argument is of type ‘int32_t *’ {aka ‘int *’}
#   402 | int send_vec_dense(runState *s, struct OutPort *port, uint32_t *data) {
#       |                                                       ~~~~~~~~~~^~~~
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h: In function ‘send_seq_conv’:
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:753:1: warning: control reaches end of non-void function [-Wreturn-type]
#   753 | }
#       | ^
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h: In function ‘write_vec_dense’:
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:1329:13: warning: ‘val_data’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#  1329 |             generate_bitmasked_data(curr_data[k], val_data, start_pos, length);
#       |             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h: In function ‘write_seq_conv’:
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:1626:9: warning: ‘val_data’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#  1626 |         generate_bitmasked_data(curr_data[k], val_data, start_pos, length);
#       |         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Compiling without -c /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/main_0_0.c
# gcc -Wall -I/home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports -I/home/sveamari/lava/frameworks.ai.lava.lava/src/lava/proc/embedded_io -I/home/sveamari/lava/frameworks.ai.lava.lava/src/lava/proc/embedded_io/tmpk45tiaoc -Inxcore/include -D N3 -D N3B -D N3B3 -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -fcf-protection=none -fno-pie -no-pie -Os -DNDEBUG -std=c99 -o /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/main_0_0.c.o -c /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/main_0_0.c
# OBJFILES :  /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/initnetwork_0_0.c.o /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/0_nx_to_py_adapter.c.o /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/main_0_0.c.o
# gcc -Wall -Wno-address-of-packed-member -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -fcf-protection=none -fno-pie -no-pie -Os -DNDEBUG -std=c99 /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/initnetwork_0_0.c.o /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/0_nx_to_py_adapter.c.o /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/main_0_0.c.o -o /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/launcher.link nxcore/lib/Embedded-N3B3/libboot.a nxcore/lib/Embedded-N3B3/libembedded_nx.a nxcore/lib/Embedded-N3B3/liblmt.a nxcore/lib/Embedded-N3B3/libnx.a -Wl,--script=nxcore/utils/n3.linker.scr -Wl,--build-id=none -Wl,-N -nostdlib -Wl,--no-dynamic-linker
# WARNING:DRV:  ~/lava/frameworks.ai.nx.nxsdk ~/lava/lava-dnf/tutorials/lava/lib/dnf/dnf_regimes
# Compiling in directory : /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015
# Include dir is : /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports -I/home/sveamari/lava/frameworks.ai.lava.lava/src/lava/proc/embedded_io -I/home/sveamari/lava/frameworks.ai.lava.lava/src/lava/proc/embedded_io/tmpdrdrnliv
# Compiling -c /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/initnetwork_0_1.c
# gcc -Wall -I/home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports -I/home/sveamari/lava/frameworks.ai.lava.lava/src/lava/proc/embedded_io -I/home/sveamari/lava/frameworks.ai.lava.lava/src/lava/proc/embedded_io/tmpdrdrnliv -Inxcore/include -D N3 -D N3B -D N3B3 -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -fcf-protection=none -fno-pie -no-pie -Os -DNDEBUG -std=c99 -o /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/initnetwork_0_1.c.o -c /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/initnetwork_0_1.c
# Compiling without -c /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/0_py_to_nx_adapter.c
# gcc -Wall -I/home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports -I/home/sveamari/lava/frameworks.ai.lava.lava/src/lava/proc/embedded_io -I/home/sveamari/lava/frameworks.ai.lava.lava/src/lava/proc/embedded_io/tmpdrdrnliv -Inxcore/include -D N3 -D N3B -D N3B3 -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -fcf-protection=none -fno-pie -no-pie -Os -DNDEBUG -std=c99 -o /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/0_py_to_nx_adapter.c.o -c /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/0_py_to_nx_adapter.c
# In file included from /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/proc/embedded_io/tmpdrdrnliv/predefs_PyToNxAdapterModel.h:1,
#                  from /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/proc/embedded_io/spike_snips/py_to_nx_adapter.c:18:
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h: In function ‘read_graded_spike_counter’:
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:306:3: warning: implicit declaration of function ‘nx_read’ [-Wimplicit-function-declaration]
#   306 |   nx_read(&value, dst, sizeof(value));
#       |   ^~~~~~~
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:309:3: warning: implicit declaration of function ‘nx_write’ [-Wimplicit-function-declaration]
#   309 |   nx_write(dst, &value, sizeof(value));
#       |   ^~~~~~~~
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h: In function ‘send_seq_dense’:
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:543:35: warning: passing argument 6 of ‘inject_spike_for_axon’ makes integer from pointer without a cast [-Wint-conversion]
#   543 |                 port->spike_type, &data);
#       |                                   ^~~~~
#       |                                   |
#       |                                   uint32_t ** {aka unsigned int **}
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:366:36: note: expected ‘uint32_t’ {aka ‘unsigned int’} but argument is of type ‘uint32_t **’ {aka ‘unsigned int **’}
#   366 |                           uint32_t data) {
#       |                           ~~~~~~~~~^~~~
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h: In function ‘done_send_seq_dense’:
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:599:12: warning: passing argument 1 of ‘memset’ makes pointer from integer without a cast [-Wint-conversion]
#   599 |     memset(out_buffer_idx, 0, MESSAGE_SIZE * sizeof(uint32_t));
#       |            ^~~~~~~~~~~~~~
#       |            |
#       |            uint8_t {aka unsigned char}
# In file included from /usr/include/features.h:461,
#                  from /usr/include/bits/libc-header-start.h:33,
#                  from /usr/include/stdint.h:26,
#                  from /usr/lib/gcc/x86_64-linux-gnu/9/include/stdint.h:9,
#                  from nxcore/include/n3sdk.h:31,
#                  from nxcore/include/nxsdk.h:30,
#                  from /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/0_py_to_nx_adapter.c:1:
# /usr/include/bits/string_fortified.h:59:1: note: expected ‘void *’ but argument is of type ‘uint8_t’ {aka ‘unsigned char’}
#    59 | __NTH (memset (void *__dest, int __ch, size_t __len))
#       | ^~~~~
# In file included from /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/proc/embedded_io/tmpdrdrnliv/predefs_PyToNxAdapterModel.h:1,
#                  from /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/proc/embedded_io/spike_snips/py_to_nx_adapter.c:18:
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h: In function ‘send_seq_sparse’:
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:667:20: warning: comparison between pointer and integer
#   667 |           if (cntr == idx) {
#       |                    ^~
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:672:35: warning: passing argument 6 of ‘inject_spike_for_axon’ makes integer from pointer without a cast [-Wint-conversion]
#   672 |                 port->spike_type, &data);
#       |                                   ^~~~~
#       |                                   |
#       |                                   uint32_t ** {aka unsigned int **}
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:366:36: note: expected ‘uint32_t’ {aka ‘unsigned int’} but argument is of type ‘uint32_t **’ {aka ‘unsigned int **’}
#   366 |                           uint32_t data) {
#       |                           ~~~~~~~~~^~~~
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h: In function ‘send_seq_conv’:
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:735:24: warning: suggest parentheses around arithmetic in operand of ‘|’ [-Wparentheses]
#   735 |   axon = 0x4000 | axon & 0xFF;
#       |                   ~~~~~^~~~~~
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:736:60: warning: suggest parentheses around arithmetic in operand of ‘|’ [-Wparentheses]
#   736 |   uint64_t encoded_data = (payload & 0xFFFF) << 16 | *data & 0xFFFF;
#       |                                                      ~~~~~~^~~~~~~~
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h: In function ‘recv_vec_dense’:
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:826:20: warning: comparison between pointer and integer
#   826 |         if (header != SEQ_DENSE) {
#       |                    ^~
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h: In function ‘recv_seq_sparse’:
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:1127:20: warning: comparison between pointer and integer
#  1127 |           if (cntr == idx) {
#       |                    ^~
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h: In function ‘send_seq_conv’:
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:753:1: warning: control reaches end of non-void function [-Wreturn-type]
#   753 | }
#       | ^
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h: In function ‘write_vec_dense’:
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:1329:13: warning: ‘val_data’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#  1329 |             generate_bitmasked_data(curr_data[k], val_data, start_pos, length);
#       |             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h: In function ‘write_seq_conv’:
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:1626:9: warning: ‘val_data’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#  1626 |         generate_bitmasked_data(curr_data[k], val_data, start_pos, length);
#       |         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Compiling without -c /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/main_0_1.c
# gcc -Wall -I/home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports -I/home/sveamari/lava/frameworks.ai.lava.lava/src/lava/proc/embedded_io -I/home/sveamari/lava/frameworks.ai.lava.lava/src/lava/proc/embedded_io/tmpdrdrnliv -Inxcore/include -D N3 -D N3B -D N3B3 -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -fcf-protection=none -fno-pie -no-pie -Os -DNDEBUG -std=c99 -o /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/main_0_1.c.o -c /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/main_0_1.c
# OBJFILES :  /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/initnetwork_0_1.c.o /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/0_py_to_nx_adapter.c.o /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/main_0_1.c.o
# gcc -Wall -Wno-address-of-packed-member -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -fcf-protection=none -fno-pie -no-pie -Os -DNDEBUG -std=c99 /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/initnetwork_0_1.c.o /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/0_py_to_nx_adapter.c.o /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/main_0_1.c.o -o /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/launcher.link nxcore/lib/Embedded-N3B3/libboot.a nxcore/lib/Embedded-N3B3/libembedded_nx.a nxcore/lib/Embedded-N3B3/liblmt.a nxcore/lib/Embedded-N3B3/libnx.a -Wl,--script=nxcore/utils/n3.linker.scr -Wl,--build-id=none -Wl,-N -nostdlib -Wl,--no-dynamic-linker
# WARNING:DRV:  ~/lava/frameworks.ai.nx.nxsdk ~/lava/lava-dnf/tutorials/lava/lib/dnf/dnf_regimes
# Compiling in directory : /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015
# Include dir is : /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports -I/home/sveamari/lava/frameworks.ai.lava.lava/src/lava/proc/embedded_io -I/home/sveamari/lava/frameworks.ai.lava.lava/src/lava/proc/embedded_io/tmpxsz6yoto
# Compiling -c /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/initnetwork_0_2.c
# gcc -Wall -I/home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports -I/home/sveamari/lava/frameworks.ai.lava.lava/src/lava/proc/embedded_io -I/home/sveamari/lava/frameworks.ai.lava.lava/src/lava/proc/embedded_io/tmpxsz6yoto -Inxcore/include -D N3 -D N3B -D N3B3 -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -fcf-protection=none -fno-pie -no-pie -Os -DNDEBUG -std=c99 -o /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/initnetwork_0_2.c.o -c /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/initnetwork_0_2.c
# Compiling without -c /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/0_py_to_nx_adapter.c
# gcc -Wall -I/home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports -I/home/sveamari/lava/frameworks.ai.lava.lava/src/lava/proc/embedded_io -I/home/sveamari/lava/frameworks.ai.lava.lava/src/lava/proc/embedded_io/tmpxsz6yoto -Inxcore/include -D N3 -D N3B -D N3B3 -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -fcf-protection=none -fno-pie -no-pie -Os -DNDEBUG -std=c99 -o /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/0_py_to_nx_adapter.c.o -c /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/0_py_to_nx_adapter.c
# In file included from /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/proc/embedded_io/tmpxsz6yoto/predefs_PyToNxAdapterModel.h:1,
#                  from /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/proc/embedded_io/spike_snips/py_to_nx_adapter.c:18:
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h: In function ‘read_graded_spike_counter’:
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:306:3: warning: implicit declaration of function ‘nx_read’ [-Wimplicit-function-declaration]
#   306 |   nx_read(&value, dst, sizeof(value));
#       |   ^~~~~~~
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:309:3: warning: implicit declaration of function ‘nx_write’ [-Wimplicit-function-declaration]
#   309 |   nx_write(dst, &value, sizeof(value));
#       |   ^~~~~~~~
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h: In function ‘send_seq_dense’:
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:543:35: warning: passing argument 6 of ‘inject_spike_for_axon’ makes integer from pointer without a cast [-Wint-conversion]
#   543 |                 port->spike_type, &data);
#       |                                   ^~~~~
#       |                                   |
#       |                                   uint32_t ** {aka unsigned int **}
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:366:36: note: expected ‘uint32_t’ {aka ‘unsigned int’} but argument is of type ‘uint32_t **’ {aka ‘unsigned int **’}
#   366 |                           uint32_t data) {
#       |                           ~~~~~~~~~^~~~
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h: In function ‘done_send_seq_dense’:
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:599:12: warning: passing argument 1 of ‘memset’ makes pointer from integer without a cast [-Wint-conversion]
#   599 |     memset(out_buffer_idx, 0, MESSAGE_SIZE * sizeof(uint32_t));
#       |            ^~~~~~~~~~~~~~
#       |            |
#       |            uint8_t {aka unsigned char}
# In file included from /usr/include/features.h:461,
#                  from /usr/include/bits/libc-header-start.h:33,
#                  from /usr/include/stdint.h:26,
#                  from /usr/lib/gcc/x86_64-linux-gnu/9/include/stdint.h:9,
#                  from nxcore/include/n3sdk.h:31,
#                  from nxcore/include/nxsdk.h:30,
#                  from /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/0_py_to_nx_adapter.c:1:
# /usr/include/bits/string_fortified.h:59:1: note: expected ‘void *’ but argument is of type ‘uint8_t’ {aka ‘unsigned char’}
#    59 | __NTH (memset (void *__dest, int __ch, size_t __len))
#       | ^~~~~
# In file included from /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/proc/embedded_io/tmpxsz6yoto/predefs_PyToNxAdapterModel.h:1,
#                  from /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/proc/embedded_io/spike_snips/py_to_nx_adapter.c:18:
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h: In function ‘send_seq_sparse’:
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:667:20: warning: comparison between pointer and integer
#   667 |           if (cntr == idx) {
#       |                    ^~
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:672:35: warning: passing argument 6 of ‘inject_spike_for_axon’ makes integer from pointer without a cast [-Wint-conversion]
#   672 |                 port->spike_type, &data);
#       |                                   ^~~~~
#       |                                   |
#       |                                   uint32_t ** {aka unsigned int **}
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:366:36: note: expected ‘uint32_t’ {aka ‘unsigned int’} but argument is of type ‘uint32_t **’ {aka ‘unsigned int **’}
#   366 |                           uint32_t data) {
#       |                           ~~~~~~~~~^~~~
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h: In function ‘send_seq_conv’:
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:735:24: warning: suggest parentheses around arithmetic in operand of ‘|’ [-Wparentheses]
#   735 |   axon = 0x4000 | axon & 0xFF;
#       |                   ~~~~~^~~~~~
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:736:60: warning: suggest parentheses around arithmetic in operand of ‘|’ [-Wparentheses]
#   736 |   uint64_t encoded_data = (payload & 0xFFFF) << 16 | *data & 0xFFFF;
#       |                                                      ~~~~~~^~~~~~~~
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h: In function ‘recv_vec_dense’:
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:826:20: warning: comparison between pointer and integer
#   826 |         if (header != SEQ_DENSE) {
#       |                    ^~
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h: In function ‘recv_seq_sparse’:
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:1127:20: warning: comparison between pointer and integer
#  1127 |           if (cntr == idx) {
#       |                    ^~
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h: In function ‘send_seq_conv’:
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:753:1: warning: control reaches end of non-void function [-Wreturn-type]
#   753 | }
#       | ^
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h: In function ‘write_vec_dense’:
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:1329:13: warning: ‘val_data’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#  1329 |             generate_bitmasked_data(curr_data[k], val_data, start_pos, length);
#       |             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h: In function ‘write_seq_conv’:
# /home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports/ports.h:1626:9: warning: ‘val_data’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#  1626 |         generate_bitmasked_data(curr_data[k], val_data, start_pos, length);
#       |         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Compiling without -c /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/main_0_2.c
# gcc -Wall -I/home/sveamari/lava/frameworks.ai.lava.lava/src/lava/magma/runtime/runtime_services/../../core/process/ports -I/home/sveamari/lava/frameworks.ai.lava.lava/src/lava/proc/embedded_io -I/home/sveamari/lava/frameworks.ai.lava.lava/src/lava/proc/embedded_io/tmpxsz6yoto -Inxcore/include -D N3 -D N3B -D N3B3 -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -fcf-protection=none -fno-pie -no-pie -Os -DNDEBUG -std=c99 -o /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/main_0_2.c.o -c /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/main_0_2.c
# OBJFILES :  /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/initnetwork_0_2.c.o /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/0_py_to_nx_adapter.c.o /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/main_0_2.c.o
# gcc -Wall -Wno-address-of-packed-member -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -fcf-protection=none -fno-pie -no-pie -Os -DNDEBUG -std=c99 /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/initnetwork_0_2.c.o /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/0_py_to_nx_adapter.c.o /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/main_0_2.c.o -o /home/sveamari/lava/frameworks.ai.nx.nxsdk/nxcore/arch/base/pre_execution/../../../../temp/93e30e98-4887-11ed-bc43-dd9a32d49015/launcher.link nxcore/lib/Embedded-N3B3/libboot.a nxcore/lib/Embedded-N3B3/libembedded_nx.a nxcore/lib/Embedded-N3B3/liblmt.a nxcore/lib/Embedded-N3B3/libnx.a -Wl,--script=nxcore/utils/n3.linker.scr -Wl,--build-id=none -Wl,-N -nostdlib -Wl,--no-dynamic-linker

# %% [markdown]
# ## Memory
#
# This example demonstrates the memory property of DNFs. The input and connectivity is structured like in the example on 'detection' above but here the local excitation is stronger. This leads to the two peaks in the DNF to remain stable even after the input is deactivated in time step 400. The DNF has thus formed a memory of the inputs being present at those locations. Even though such self-sustained peaks are stable without input, they may track present input that changes its location in a graded manner.

# %%
memory_kernel = MultiPeakKernel(amp_exc=32, 
                                width_exc=2.5, 
                                amp_inh=-18, 
                                width_inh=4.5)

architecture = Architecture(memory_kernel)
architecture.run()
architecture.plot()

# %% [markdown]
# ## Selection
#
# This example demonstrates the _selection instability_ of a DNF. With spike input at two locations, the DNF makes a selection decision at time step 100, creating a peak at only one of the input locations. That decision remains stable even though two inputs are present simultaneously for the subsequent 100 time steps. The selection switches only when the first input is deactivates at time step 200. It then remains stable on the second input location even as the first input is activated again at time step 300. This demonstrates hysteresis of selection - the DNF stabilizes its selection decision. The same behavior is demonstrated again between time step 400 and 600 for the first input.
#
# Note: The selection is biased/forced here to always be on the input centered on neuron 11 to fit the structure of the input. To achieve this, this input is activated one time step before the other input. If both were activated at the same time step the selection decision would be random. The DNF may then select the "wrong" input and the example would not work.

# %%
from lava.lib.dnf.kernels.kernels import SelectiveKernel

class SelectiveArchitecture(Architecture):
    """Class that overrides the run function to specify a different input
    structure."""
    def run(self):
        # Run the network and make changes to spike inputs over time
        self.dnf.run(condition=RunSteps(num_steps=99), run_cfg=self.run_cfg)
        self.gauss_pattern_1.amplitude = 10000
        self.dnf.run(condition=RunSteps(num_steps=1), run_cfg=self.run_cfg)
        self.gauss_pattern_2.amplitude = 10000
        self.dnf.run(condition=RunSteps(num_steps=100), run_cfg=self.run_cfg)
        self.gauss_pattern_1.amplitude = 0
        self.dnf.run(condition=RunSteps(num_steps=100), run_cfg=self.run_cfg)
        self.gauss_pattern_1.amplitude = 10000
        self.dnf.run(condition=RunSteps(num_steps=100), run_cfg=self.run_cfg)
        self.gauss_pattern_2.amplitude = 0
        self.dnf.run(condition=RunSteps(num_steps=100), run_cfg=self.run_cfg)
        self.gauss_pattern_2.amplitude = 10000
        self.dnf.run(condition=RunSteps(num_steps=100), run_cfg=self.run_cfg)
        self.gauss_pattern_1.amplitude = 0
        self.gauss_pattern_2.amplitude = 0
        self.dnf.run(condition=RunSteps(num_steps=100), run_cfg=self.run_cfg)


selection_kernel = SelectiveKernel(amp_exc=20, 
                                   width_exc=2.25, 
                                   global_inh=-15)

architecture = SelectiveArchitecture(selection_kernel)
architecture.run()
architecture.plot()
